# %% [markdown]
# <a href="https://colab.research.google.com/github/Farmhouse121/Adventures-in-Financial-Data-Science/blob/main/Alphas/Market_Return_by_Political_Party.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from my_library import *
# Out:
# 16:29:55 Starting...
# 16:29:55 Installing yfinance into Google notebook...
# 16:30:00 Installing arch into Google notebook...
# 16:30:10 Initialized.

# %% [markdown]
# ### Get Presidents Data

# %%
presidents=(p:=pd.read_html('https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States')[0]).set_index(p.columns[0]).iloc[:,[1,2,4]]
presidents['Term Begins']=presidents.iloc[:,1].apply(lambda x:pd.Period(" ".join(x.split(' ')[:3]).split("[")[0],'D'))
presidents['Term Ends']=presidents.iloc[:,1].apply(lambda x:pd.Period(" ".join(x.split(' ')[4:]).split("[")[0] if 'Incumbent' not in x else today(),'D'))
presidents['Party']=presidents.iloc[:,2].str.replace(r"\[.+\]","",regex=True)
presidents['President']=presidents[presidents.columns[0]].apply(lambda x:x.split(' (')[0])
presidents=presidents[presidents.columns[-4:]]
presidents.index.name='President'
display(presidents)
# Out:
#           Term Begins   Term Ends                                       Party  \
# President
# 1          1789-04-30  1797-03-04                                Unaffiliated
# 2          1797-03-04  1801-03-04                                  Federalist
# 3          1801-03-04  1809-03-04                      Democratic- Republican
# 4          1809-03-04  1817-03-04                      Democratic- Republican
# 5          1817-03-04  1825-03-04                      Democratic- Republican
# 6          1825-03-04  1829-03-04  Democratic- Republican National Republican
# 7          1829-03-04  1837-03-04                                  Democratic
# 8          1837-03-04  1841-03-04                                  Democratic
# 9          1841-03-04  1841-04-04                                        Whig
# 10         1841-04-04  1845-03-04                           Whig Unaffiliated
# 11         1845-03-04  1849-03-04                                  Democratic
# 12         1849-03-04  1850-07-09                                        Whig
# 13         1850-07-09  1853-03-04                                        Whig
# 14         1853-03-04  1857-03-04                                  Democratic
# 15         1857-03-04  1861-03-04                                  Democratic
# 16         1861-03-04  1865-04-15                   Republican National Union
# 17         1865-04-15  1869-03-04                   National Union Democratic
# 18         1869-03-04  1877-03-04                                  Republican
# 19         1877-03-04  1881-03-04                                  Republican
# 20         1881-03-04  1881-09-19                                  Republican
# 21         1881-09-19  1885-03-04                                  Republican
# 22         1885-03-04  1889-03-04                                  Democratic
# 23         1889-03-04  1893-03-04                                  Republican
# 24         1893-03-04  1897-03-04                                  Democratic
# 25         1897-03-04  1901-09-14                                  Republican
# 26         1901-09-14  1909-03-04                                  Republican
# 27         1909-03-04  1913-03-04                                  Republican
# 28         1913-03-04  1921-03-04                                  Democratic
# 29         1921-03-04  1923-08-02                                  Republican
# 30         1923-08-02  1929-03-04                                  Republican
# 31         1929-03-04  1933-03-04                                  Republican
# 32         1933-03-04  1945-04-12                                  Democratic
# 33         1945-04-12  1953-01-20                                  Democratic
# 34         1953-01-20  1961-01-20                                  Republican
# 35         1961-01-20  1963-11-22                                  Democratic
# 36         1963-11-22  1969-01-20                                  Democratic
# 37         1969-01-20  1974-08-09                                  Republican
# 38         1974-08-09  1977-01-20                                  Republican
# 39         1977-01-20  1981-01-20                                  Democratic
# 40         1981-01-20  1989-01-20                                  Republican
# 41         1989-01-20  1993-01-20                                  Republican
# 42         1993-01-20  2001-01-20                                  Democratic
# 43         2001-01-20  2009-01-20                                  Republican
# 44         2009-01-20  2017-01-20                                  Democratic
# 45         2017-01-20  2021-01-20                                  Republican
# 46         2021-01-20  2025-01-20                                  Democratic
# 47         2025-01-20  2025-04-03                                  Republican
#
#                         President
# President
# 1               George Washington
# 2                      John Adams
# 3                Thomas Jefferson
# 4                   James Madison
# 5                    James Monroe
# 6               John Quincy Adams
# 7                  Andrew Jackson
# 8                Martin Van Buren
# 9          William Henry Harrison
# 10                     John Tyler
# 11                  James K. Polk
# 12                 Zachary Taylor
# 13               Millard Fillmore
# 14                Franklin Pierce
# 15                 James Buchanan
# 16                Abraham Lincoln
# 17                 Andrew Johnson
# 18               Ulysses S. Grant
# 19            Rutherford B. Hayes
# 20              James A. Garfield
# 21              Chester A. Arthur
# 22               Grover Cleveland
# 23              Benjamin Harrison
# 24               Grover Cleveland
# 25               William McKinley
# 26             Theodore Roosevelt
# 27            William Howard Taft
# 28                 Woodrow Wilson
# 29              Warren G. Harding
# 30                Calvin Coolidge
# 31                 Herbert Hoover
# 32          Franklin D. Roosevelt
# 33                Harry S. Truman
# 34           Dwight D. Eisenhower
# 35                John F. Kennedy
# 36              Lyndon B. Johnson
# 37                  Richard Nixon
# 38                    Gerald Ford
# 39                   Jimmy Carter
# 40                  Ronald Reagan
# 41              George H. W. Bush
# 42                   Bill Clinton
# 43                 George W. Bush
# 44                   Barack Obama
# 45                   Donald Trump
# 46                      Joe Biden
# 47                   Donald Trump

# %% [markdown]
# ### Get Market Data

# %%
data,ticker_name=download(ticker:='^GSPC',auto_adjust=True).xs(ticker,axis=1,level=1),'S&P 500 Index'
data['Return']=data['Close'].pct_change()*hundred
data.columns.name=ticker_name
data.dropna(inplace=True)
data.index=list(map(lambda x:pd.Period(x,'D'),data.index))
display(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# S&P 500 Index        Close         High          Low         Open      Volume  \
# 1928-01-03       17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04       17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05       17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06       17.660000    17.660000    17.660000    17.660000           0
# 1928-01-09       17.500000    17.500000    17.500000    17.500000           0
# ...                    ...          ...          ...          ...         ...
# 2025-03-28     5580.939941  5685.890137  5572.419922  5679.200195  4513330000
# 2025-03-31     5611.850098  5627.560059  5488.729980  5527.910156  5257250000
# 2025-04-01     5633.069824  5650.569824  5558.520020  5597.529785  4434500000
# 2025-04-02     5670.970215  5695.310059  5571.479980  5580.759766  4243830000
# 2025-04-03     5427.729980  5499.529785  5415.660156  5492.740234  2926224000
#
# S&P 500 Index    Return
# 1928-01-03     0.566254
# 1928-01-04    -0.225230
# 1928-01-05    -0.959368
# 1928-01-06     0.626784
# 1928-01-09    -0.906001
# ...                 ...
# 2025-03-28    -1.973722
# 2025-03-31     0.553852
# 2025-04-01     0.378124
# 2025-04-02     0.672819
# 2025-04-03    -4.289217
#
# [24429 rows x 6 columns]

# %% [markdown]
# ### Merge the Data and Perform Classic $t$ Test and ANOVA Analysis

# %%
from scipy.stats import t as tdensity
from statsmodels.formula.api import ols as OLSformula
from statsmodels.stats.anova import anova_lm

merged=presidents.set_index('Term Begins').merge(data,left_index=True,right_index=True,how='outer').ffill().dropna().drop(columns='Term Ends',axis=1)
merged.index.name='Date'
display(merged)

nprint("t Test for Zero Mean")
groups=merged[['Party','Return']].groupby('Party')
grouped=groups.count().rename(columns={'Return':'Sample'})
grouped['Mean']=groups.mean()
grouped['Std.Dev.']=groups.std()
grouped['Variance']=groups.var()
grouped['Std.Err.']=np.sqrt(grouped['Variance']/grouped['Sample'])
grouped['t Statistic']=grouped['Mean']/grouped['Std.Err.']
grouped['p Value']=list(map(lambda x:min([x,one-x])*two,list(tdensity.cdf(grouped['t Statistic'],grouped['Sample']-one))))
grouped['Significance']=grouped['p Value'].apply(lambda x:'***' if x<=0.001 else '**' if x<=0.01 else '*' if x<0.05 else '')
grouped.index.name='Groups'
display(grouped.sort_values("p Value"))

nprint("One Way ANOVA Analysis")
fit=OLSformula("Return ~ Party",merged).fit()
anova=anova_lm(fit,typ=2).rename(columns={'sum_sq':'Sum of Squares','df':'d.o.f.','PR(>F)':'p Value','F':'F Statistic'})
anova['Significance']=anova['p Value'].apply(lambda x:'***' if x<=0.001 else '**' if x<=0.01 else '*' if x<0.05 else '')
anova.index=['Between Groups','Within Groups']
anova.index.name='Variation'
display(anova)
# Out:
#                  Party        President        Close         High  \
# Date
# 1928-01-03  Republican  Calvin Coolidge    17.760000    17.760000
# 1928-01-04  Republican  Calvin Coolidge    17.719999    17.719999
# 1928-01-05  Republican  Calvin Coolidge    17.549999    17.549999
# 1928-01-06  Republican  Calvin Coolidge    17.660000    17.660000
# 1928-01-09  Republican  Calvin Coolidge    17.500000    17.500000
# ...                ...              ...          ...          ...
# 2025-03-28  Republican     Donald Trump  5580.939941  5685.890137
# 2025-03-31  Republican     Donald Trump  5611.850098  5627.560059
# 2025-04-01  Republican     Donald Trump  5633.069824  5650.569824
# 2025-04-02  Republican     Donald Trump  5670.970215  5695.310059
# 2025-04-03  Republican     Donald Trump  5427.729980  5499.529785
#
#                     Low         Open        Volume    Return
# Date
# 1928-01-03    17.760000    17.760000  0.000000e+00  0.566254
# 1928-01-04    17.719999    17.719999  0.000000e+00 -0.225230
# 1928-01-05    17.549999    17.549999  0.000000e+00 -0.959368
# 1928-01-06    17.660000    17.660000  0.000000e+00  0.626784
# 1928-01-09    17.500000    17.500000  0.000000e+00 -0.906001
# ...                 ...          ...           ...       ...
# 2025-03-28  5572.419922  5679.200195  4.513330e+09 -1.973722
# 2025-03-31  5488.729980  5527.910156  5.257250e+09  0.553852
# 2025-04-01  5558.520020  5597.529785  4.434500e+09  0.378124
# 2025-04-02  5571.479980  5580.759766  4.243830e+09  0.672819
# 2025-04-03  5415.660156  5492.740234  2.926224e+09 -4.289217
#
# [24432 rows x 8 columns]
# 18:45:19 t Test for Zero Mean
#             Sample      Mean  Std.Dev.  Variance  Std.Err.  t Statistic  \
# Groups
# Democratic   12998  0.043842  1.120798  1.256188  0.009831     4.459698
# Republican   11434  0.015847  1.270476  1.614110  0.011881     1.333762
#
#              p Value Significance
# Groups
# Democratic  0.000008          ***
# Republican  0.182309
# 18:45:19 One Way ANOVA Analysis
#                 Sum of Squares   d.o.f.  F Statistic   p Value Significance
# Variation
# Between Groups        4.767506      1.0     3.348691  0.067271
# Within Groups     34780.805076  24430.0          NaN       NaN

# %%
# Out:
#             Return      Mean  Variance
# Party
# Democratic   12998  0.043842  1.256188
# Republican   11434  0.015847  1.614110
